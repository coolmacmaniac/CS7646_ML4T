# %%
import pandas as pd
import matplotlib.pyplot as plt
from util import data

# %matplotlib inline
# plt.style.use('bmh')
# plt.style.use('seaborn-v0_8')
plt.style.use('ggplot')
plt.rcParams['figure.figsize'] = (12, 8)

# %%
dates = pd.date_range(start='2010-01-04', end='2012-09-12')
df = data.get_data(['GOOG'], dates)

# %%
df.tail(20)
# Out:
#                SPY    GOOG
# 2012-08-15  140.95  667.54
# 2012-08-16  141.99  672.87
# 2012-08-17  142.18  677.14
# 2012-08-20  142.19  675.54
# 2012-08-21  141.76  669.51
# 2012-08-22  141.82  677.18
# 2012-08-23  140.66  676.80
# 2012-08-24  141.51  678.63
# 2012-08-27  141.54  669.22
# 2012-08-28  141.40  677.25
# 2012-08-29  141.51  688.01
# 2012-08-30  140.49  681.68
# 2012-08-31  141.16  685.09
# 2012-09-04  141.03  681.04
# 2012-09-05  140.91  680.72
# 2012-09-06  143.77  699.40
# 2012-09-07  144.33  706.15
# 2012-09-10  143.51  700.77
# 2012-09-11  143.91  692.19
# 2012-09-12  144.39  690.88

# %%
data.plot_data(df)

# %% [markdown]
# ---
